# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from utils import *

# %%
sns.set_theme(style="whitegrid", palette="pastel")

# %%
path = "C:\\Users\\USER\\Documents\\GitHub\\mulherescomputacao\\Formulario\\docentes.csv"
df = pd.read_csv(path, encoding='ISO-8859-1', sep=';')

# %%
df['codes'] = df['codes'].str.split(', ')
tag_counts = df['codes'].explode().value_counts()
df_result = pd.DataFrame({'Tag': tag_counts.index, 'Count': tag_counts.values})

# %%
df_result.to_csv('qtd_codes_docentes.csv')

# %%
df_filt = pd.read_csv('qtd_codes_docentes.csv')

# %%
barplot_multilabel(df_filt,
                    y='Tag', x='Count', title='Docentes', 
                    ylabel='Código', xlabel='Quantidade de ocorrências',figsize=(3,4))
