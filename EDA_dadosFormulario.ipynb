# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
path = "C:\\Users\\USER\\Documents\\GitHub\\mulherescomputacao\\Respostas_Forms.csv"
df = pd.read_csv(path)

# %%
sns.set_theme(style="whitegrid", palette="pastel")

# %%
df["ANO_FORMATURA"] = pd.to_numeric(df["ANO_FORMATURA"])

# %%
df["TEMPO_NA_UFES"] = df["ANO_FORMATURA"] - df["ANO_INGRESSO"]

# %%
df["TEMPO_NA_UFES"].describe()
# Out:
# count    29.000000
# mean      5.586207
# std       1.637010
# min       3.000000
# 25%       5.000000
# 50%       5.000000
# 75%       6.000000
# max      10.000000
# Name: TEMPO_NA_UFES, dtype: float64

# %%
df.columns
# Out:
# Index(['Carimbo de data/hora', 'ETINIA', 'RENDA_FAMILIAR', 'TRABALHOU_GRAD',
#        'TEVE_AUXUILIO', 'TIPO_AUXILIO', 'BOLSISTA', 'TIPO_BOLSA',
#        'TIPO_INST_EM', 'INICIATIVA_FOMENTO', 'TIPO_INICIATIVA',
#        'IMPORTANCIA_INICIATIVA', 'FATORES_ESCOLHA', 'ANO_INGRESSO',
#        'IDADE_INGRESSO', 'COTISTA', 'TIPO_COTA', 'METODO_INGRESSO',
#        'VINCULO_ATUAL_UFES', 'ATUACAO_AREA', 'CARREIRA_ACADEMICA',
#        'ESCOLARIDADE_ATUAL', 'ATIVIDADE_ATUAL', 'FATORES_DESISTENCIA',
#        'PORCENTAGEM_CURSO', 'DIFICULDADES_GRAD', 'TIPO_EP_DOCENTE',
#        'DESCRICAO_EP_DOCENTE', 'PRESENCIOU_EP_DOCENTE', 'TIPO_EP_DISCENTE',
#        'DESCRICAO_EP_DISCENTE', 'SUGESTÕES', 'EMAIL', 'PRECENCIOU_EP_DISCENTE',
#        'ANO_FORMATURA', 'TEMPO_NA_UFES'],
#       dtype='object')

# %%
sns.histplot(df, x='ANO_INGRESSO', hue="COTISTA",multiple="stack",bins=33)
# Out:
# <AxesSubplot:xlabel='ANO_INGRESSO', ylabel='Count'>

# %%
sns.histplot(df, x='ANO_INGRESSO', hue="TEVE_AUXUILIO",multiple="stack",bins=33)
# Out:
# <AxesSubplot:xlabel='ANO_INGRESSO', ylabel='Count'>

# %%
sns.histplot(df, x='ANO_INGRESSO', hue="PRESENCIOU_EP_DOCENTE",multiple="stack",bins=33)
# Out:
# <AxesSubplot:xlabel='ANO_INGRESSO', ylabel='Count'>

# %%
sns.histplot(df, x='ANO_INGRESSO', hue="PRECENCIOU_EP_DISCENTE",multiple="stack",bins=33)
# Out:
# <AxesSubplot:xlabel='ANO_INGRESSO', ylabel='Count'>

# %%
sns.histplot(df, x='ANO_INGRESSO', hue="CARREIRA_ACADEMICA",multiple="stack",bins=33)
# Out:
# <AxesSubplot:xlabel='ANO_INGRESSO', ylabel='Count'>

# %%
sns.histplot(df, x='ANO_INGRESSO', hue="CARREIRA_ACADEMICA",multiple="stack",bins=33)
# Out:
# <AxesSubplot:xlabel='ANO_INGRESSO', ylabel='Count'>
