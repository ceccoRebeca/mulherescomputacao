# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
path = "C:\\Users\\USER\\Documents\\GitHub\\mulherescomputacao\Mulheres na Computação (respostas) - Respostas ao formulário 1.csv"
df = pd.read_csv(path)

# %%
df
# Out:
#    Carimbo de data/hora Qual etnia que se declara?  \
# 0   18/10/2022 12:29:50                     Branca
# 1   18/10/2022 14:58:26                     Branca
# 2   18/10/2022 16:01:01                     Branca
# 3   19/10/2022 17:50:58                     Branca
# 4   20/10/2022 07:10:33                     Branca
# ..                  ...                        ...
# 67  22/12/2022 11:25:09                     Branca
# 68  22/12/2022 14:48:22                     Branca
# 69  22/12/2022 15:01:37                      Preta
# 70  23/12/2022 01:54:45                      Parda
# 71  27/12/2022 12:43:23                      Parda
#
#    Qual era a sua renda familiar antes e durante o período da faculdade?  \
# 0   De 4,5 a 6 salários mínimos (De R$ 5.454,00 at...
# 1   De 1,5 a 3 salários mínimos (De R$ 1.818,00 at...
# 2   De 1,5 a 3 salários mínimos (De R$ 1.818,00 at...
# 3            Até 1,5 salário mínimo (até R$ 1.818,00)
# 4   De 1,5 a 3 salários mínimos (De R$ 1.818,00 at...
# ...

# %%
plt.pie(data=df["Qual etnia que se declara?"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [4], line 1
# ----> 1 plt.pie(data=df["Qual etnia que se declara?"])
#
# TypeError: pie() missing 1 required positional argument: 'x'
