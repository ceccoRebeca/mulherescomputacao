# %%
import pandas as pd
import seaborn as sns
import streamlit as st

# %%
path = "C:\\Users\\USER\\Documents\\GitHub\\mulherescomputacao\\DadosRebeca.csv"
df = pd.read_csv(path)

# %%
df
# Out:
#       NOME_ALUNO SEXO  IDADE (ao ingressar) ESTADO_CIVIL (ao ingressar)  \
# 0        Aluno 1    M                  19.3                   Casado(a)
# 1        Aluno 2    M                  23.0                 Solteiro(a)
# 2        Aluno 3    M                  20.7                 Solteiro(a)
# 3        Aluno 4    M                  17.2                 Solteiro(a)
# 4        Aluno 5    M                  25.8                 Solteiro(a)
# ...          ...  ...                   ...                         ...
# 2456  Aluno 2457    M                  18.0                 Solteiro(a)
# 2457  Aluno 2458    M                  17.9                 Solteiro(a)
# 2458  Aluno 2459    M                  18.6                 Solteiro(a)
# 2459  Aluno 2460    M                  18.0                 Solteiro(a)
# 2460  Aluno 2461    M                  19.5                 Solteiro(a)
#
#        ETNIA  COD_CURSO                NOME_CURSO  ANO_INGRESSO  \
# 0     Branca          5  Engenharia de Computação          2007
# 1     Branca          5  Engenharia de Computação          2007
# 2     Branca          5  Engenharia de Computação          2008
# 3      Parda          5  Engenharia de Computação          2008
# 4      Parda          5  Engenharia de Computação          2008
# ...      ...        ...                       ...           ...
# 2456   Parda         11     Ciência da Computação          2013
# 2457  Branca         11     Ciência da Computação          2013
# 2458   Parda         11     Ciência da Computação          2013
# 2459   Preta         11     Ciência da Computação          2013
# 2460  Branca         11     Ciência da Computação          2013
#
#      FORMA_INGRESSO PERIODO_INGRESSO  ...  NUM_PERIODOS NUM_MAX_PERIODOS  \
# 0        Vestibular      1º Semestre  ...            10               18
# 1        Vestibular      1º Semestre  ...            10               18
# 2        Vestibular      1º Semestre  ...            10               15
# 3        Vestibular      1º Semestre  ...            10               18
# 4        Vestibular      1º Semestre  ...            10               15
# ...             ...              ...  ...           ...              ...
# 2456     Vestibular      1º Semestre  ...             9               13
# 2457     Vestibular      1º Semestre  ...             9               13
# 2458     Vestibular      1º Semestre  ...             9               13
# 2459     Vestibular      1º Semestre  ...             9               13
# 2460     Vestibular      1º Semestre  ...             9               13
#
#      CH_TOTAL_CURSO  COTISTA     MUNICIPIO          ESTADO    PAIS      CRN  \
# 0              3690        N    VILA VELHA  Espirito Santo  Brasil  14,3369
# 1              3690        N       VITORIA  Espirito Santo  Brasil  15,8809
# 2              4215        N     CARIACICA  Espirito Santo  Brasil   2,3339
# 3              3690        S  NOVA VENECIA  Espirito Santo  Brasil  16,1175
# 4              4215        N         SERRA  Espirito Santo  Brasil   1,3823
# ...             ...      ...           ...             ...     ...      ...
# 2456           3590        N    VILA VELHA  Espirito Santo  Brasil  3332700
# 2457           3590        N         SERRA  Espírito Santo  Brasil   3,5087
# 2458           3590        N       VITORIA  Espirito Santo  Brasil   2,4607
# 2459           3590        S        ALEGRE  Espírito Santo  Brasil    2,117
# 2460           3590        S    VILA VELHA  Espirito Santo  Brasil  14,3753
#
#        CRA QTDE_TRANCAMENTOS
# 0     5.62                 0
# 1     7.88                 0
# 2     2.75                 1
# 3     8.03                 0
# 4     1.71                 0
# ...    ...               ...
# 2456  3.02                 1
# 2457  3.50                 1
# 2458  1.90                 1
# 2459  1.20                 0
# 2460  6.10                 0
#
# [2461 rows x 23 columns]
